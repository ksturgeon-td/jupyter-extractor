# %% [markdown]
# # Data Exploration with Pandas
#
# This notebook demonstrates basic data loading, inspection, and visualization.

# %% [markdown]
# ## Setup
#
# Import the required libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data
#
# Create a sample DataFrame for demonstration.

# %%
df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Carol'],
    'age': [25, 30, 22],
    'score': [88.5, 72.0, 95.3]
})
df
# Out:
#    name  age  score
# 0  Alice   25   88.5
# 1    Bob   30   72.0
# 2  Carol   22   95.3

# %%
print(f'Shape: {df.shape}')
print(f'Mean score: {df["score"].mean():.2f}')
# Out:
# Shape: (3, 3)
# Mean score: 85.27

# %% [markdown]
# ## Error Example
#
# Showing what an error output looks like.

# %%
df['missing_column']
# Out:
# Traceback (most recent call last):
#   File "<ipython-input>", line 1, in <module>
# KeyError: 'missing_column'
